# %%
from PIL import Image
import numpy as np
from numpy import array
from IPython.display import display
import cv2
import matplotlib.pyplot as plt 
import scipy
i=Image.open('testimg.jpg')
i=i.convert('RGB')
i.save('im.pgm')
path="im.pgm"
path1="testimg.jpg"
display(Image.open(path))
display(Image.open(path1))
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1280x284 at 0x6430430>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x284 at 0x6430830>

# %%
path="key.png"
i=Image.open(path)
ar=np.asarray(i)
x=np.amin(ar)
y=np.amax(ar)
print(ar)
print(x)
print(y)
# Out:
# [[[184 200 110]
#   [184 200 110]
#   [184 200 110]
#   ...
#   [ 24 175 110]
#   [ 24 175 110]
#   [ 24 175 110]]
#
#  [[184 200 110]
#   [184 200 110]
#   [184 200 110]
#   ...
#   [ 24 173 110]
#   [ 24 173 110]
#   [ 24 173 110]]
#
#  [[184 200 110]
#   [184 200 110]
#   [184 200 110]
#   ...
#   [ 24 171 110]
#   [ 24 171 110]
#   [ 24 171 110]]
#
#  ...
#
#  [[152  56 110]
#   [152  56 110]
#   [152  56 110]
#   ...
#   [ 96  29 110]
#   [ 96  29 110]
#   [ 96  29 110]]
#
#  [[152  56 110]
#   [152  56 110]
#   [152  56 110]
#   ...
#   [ 96  27 110]
#   [ 96  27 110]
#   [ 96  27 110]]
#
#  [[152  56 110]
#   [152  56 110]
#   [152  56 110]
#   ...
#   [ 96  25 110]
#   [ 96  25 110]
#   [ 96  25 110]]]
# 9
# 247

# %%
from itertools import chain
import numpy as np
from PIL import Image
import sys
col=Image.open("key.png")
gray=col.convert('L')
bw=gray.point(lambda x: 1 if x<128 else 0, '1')
bw.save("newkey.png")
path="newkey.png"
display(Image.open(path))
ii=Image.open(path)
ar=np.asarray(ii)
#print(ar)
arr=ar.astype(int)
#print(arr)
row=len(arr)
co=len(list(zip(*arr)))
print(row)
print(co)
c=2
#print(arr)
#res={6}.issubset(chain.from_iterable(arr))
#print(arr.count(2))
#print(arr.count(3))
#print(arr.count(4))
#print(arr.count(5))
#print(arr.count(6))
#np.set_printoptions(threshold=sys.maxsize)
#print(arr)
u=np.unique(arr)
print(u)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=1280x720 at 0x1ABF9052DF0>
# 720
# 1280
# [0 1]
