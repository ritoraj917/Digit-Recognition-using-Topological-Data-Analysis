# %%
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=1280x483 at 0xB4DA370>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0671c2584541> in <module>
#       9 im=Image.open(path)
#      10 img=cv2.imread(path,0)
# ---> 11 otsu_thr,otsu_mask=cv2.threshold(img,-1,1,v2.THRESH_BINARY | cv2.THRESH_OTSU)
#      12 print('Estimated threshold otsu:',otsu_thr)
#      13 plt.figure(figsize=(6,3))
#
# NameError: name 'v2' is not defined

# %%
from PIL import Image
import numpy as np
from numpy import array
from IPython.display import display
import cv2
import matplotlib.pyplot as plt 
path="image.pgm"
display(Image.open(path))
im=Image.open(path)
img=cv2.imread(path,0)
otsu_thr,otsu_mask=cv2.threshold(img,-1,1,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
print('Estimated threshold otsu:',otsu_thr)
plt.figure(figsize=(6,3))
plt.subplot(121)
plt.axis('off')
plt.title('original')
plt.imshow(img,cmap='gray')
plt.subplot(122)
plt.axis('off')
plt.title('otsu threshold')
plt.imshow(otsu_mask,cmap='gray')
plt.tight_layout()
plt.show()
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=L size=1280x483 at 0xC4BC7D0>
# Estimated threshold otsu: 45.0
